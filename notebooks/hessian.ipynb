# %% [markdown]
# # Hessian metrics of the Models
# In this notebook we observe the results of the Hessian metrics among models.

# %%
# %reload_ext autoreload
# %autoreload 2

# %%
import os
import sys
module_path = os.path.abspath(os.path.join('..'))
sys.path.insert(0, module_path)
from plotting_utility import *

# %% [markdown]
# # ECON-T (lossy data compression)

# %%
tags = ["baseline", "JREG_0.1", "LIP_0.00001"]
load_metrics("ECON", tags, 1024, 0.0015625)
# Out:
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_4b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_4b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_4b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_4b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_JREG_0.1_4b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_JREG_0.1_4b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_JREG_0.1_4b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_JREG_0.1_4b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_LIP_0.00001_4b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_LIP_0.00001_4b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_LIP_0.00001_4b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_LIP_0.00001_4b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_5b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_5b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_5b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_5b
# ...
# 	path: ../checkpoint/bs1024_lr0.0015625/ECON_JREG_0.1_5b
# ...

# %% [markdown]
# Load the results from the CSV: and filter it:

# %%
regularizer = ["Baseline", "Jacobian (δ=1e-1)", "Orthogonality (δ=1e-5)"]
df = pd.read_csv("./results/ECON/metrics.csv")
selected_df = df[(df['regularizer'].isin(regularizer))]

# %%
plot_precision_vs_metrics(selected_df, "regularizer", "precision", "Hessian trace", log_scale=True, plot_legend=False)

# %%
# plot_precision_vs_metrics(selected_df, "regularizer", "precision", "Top eigenvalue", log_scale=True, plot_legend=True)

# %% [markdown]
# # MobileNetV1 (CIFAR-100 classification)

# %%
tags = ["baseline", "LIP_0.0001", "JREG_0.001",]
load_metrics("MobileNet", tags, 128, 0.1)

# %%
regularizer = ["Baseline", "Jacobian (δ=1e-3)", "Orthogonality (δ=1e-4)"]
df = pd.read_csv("./results/MobileNet/metrics.csv")
selected_df = df[(df['regularizer'].isin(regularizer))]

# %%
plot_precision_vs_metrics(selected_df, "regularizer", "precision", "Hessian trace", log_scale=True, plot_legend=False)

# %% [markdown]
# # VGG 16 (CIFAR-100 classification)

# %%
tags = ["baseline", "LIP_0.0001", "JREG_0.001",]
load_metrics("VGG16", tags, 256, 0.1)
# Out:
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_4b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_4b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_4b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_4b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_LIP_0.0001_4b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_LIP_0.0001_4b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_LIP_0.0001_4b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_LIP_0.0001_4b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_JREG_0.001_4b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_JREG_0.001_4b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_JREG_0.001_4b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_JREG_0.001_4b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_5b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_5b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_5b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_5b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_LIP_0.0001_5b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_LIP_0.0001_5b
# ...
# 	path: ../checkpoint/bs256_lr0.1/VGG16_LIP_0.0001_5b
# ...

# %%
regularizer = ["Baseline", "Jacobian (δ=1e-3)", "Orthogonality (δ=1e-4)"]
df = pd.read_csv("./results/VGG16/metrics.csv")
selected_df = df[(df['regularizer'].isin(regularizer))]

# %%
plot_precision_vs_metrics(selected_df, "regularizer", "precision", "Hessian trace", log_scale=True, plot_legend=False)

# %% [markdown]
# # Fusion model (Regression)

# %%
tags = ["baseline", "JREG_0.000001", "LIP_0.000001"]
load_metrics("FUSION", tags, 32, 0.001)
# Out:
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_4b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_4b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_4b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_4b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_JREG_0.000001_4b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_JREG_0.000001_4b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_JREG_0.000001_4b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_JREG_0.000001_4b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_LIP_0.000001_4b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_LIP_0.000001_4b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_LIP_0.000001_4b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_LIP_0.000001_4b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_5b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_5b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_5b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_5b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_JREG_0.000001_5b
# ...
# 	path: ../checkpoint/bs32_lr0.001/FUSION_JREG_0.000001_5b
# ...

# %%
regularizer = ["Baseline", "Jacobian (δ=1e-6)", "Orthogonality (δ=1e-6)"]
df = pd.read_csv("./results/FUSION/metrics.csv")
selected_df = df[(df['regularizer'].isin(regularizer))]

# %%
plot_precision_vs_metrics(selected_df, "regularizer", "precision", "Hessian trace", log_scale=True, plot_legend=False)
